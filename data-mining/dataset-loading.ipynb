# %%
import numpy as np
import pandas as pd
import random
import datetime
import math
import pymongo
import string
import csv

# %%
df = pd.read_csv('simple_dataset.csv')
# Out:
#                             artist  \
# 0                   Elvis Costello
# 1  Elvis Costello  The Attractions
# 2                     Tiffany Page
# 3  Elvis Costello  The Attractions
# 4                   Elvis Costello
#
#                                               track        playlist  \
# 0                The Angels Wanna Wear My Red Shoes  HARD ROCK 2010
# 1  Whats So Funny Bout Peace Love And Understanding  HARD ROCK 2010
# 2                                  7 Years Too Late  HARD ROCK 2010
# 3                             Accidents Will Happen  HARD ROCK 2010
# 4                                            Alison  HARD ROCK 2010
#
#                                         artist_track
# 0  Elvis Costello The Angels Wanna Wear My Red Shoes
# 1  Elvis Costello  The Attractions Whats So Funny...
# 2                      Tiffany Page 7 Years Too Late
# 3  Elvis Costello  The Attractions Accidents Will...
# 4                              Elvis Costello Alison

# %%
# Connection to mongoDB, SYP database 

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient['SYP2']

# %%
df_playlist = pd.DataFrame(df)
df_playlist = df_playlist.drop_duplicates(subset=['playlist']) # Take unique playlist name 
# Generate a random date_of_creation for each playlist

start_date = datetime.datetime(2010, 1, 1)
end_date = datetime.datetime(2020, 2, 1)
time_between_dates = end_date - start_date
days_between_dates = time_between_dates.days

df_playlist['date_of_creation'] = [ (start_date + datetime.timedelta(random.randrange(days_between_dates))) for k in df_playlist.playlist]
# Drop useless columns for playlists 
df_playlist_inserted = df_playlist.drop(['artist','track'],axis=1)
df_playlist_inserted.head()
# Out:
#            playlist                                       artist_track  \
# 0    HARD ROCK 2010  Elvis Costello The Angels Wanna Wear My Red Shoes
# 67         IOW 2012                    Noah And The Whale 5 Years Time
# 104            2080                                          2080 1 Up
# 114            C418                                         C418 Alive
# 148       Chill out                                     C418 0x10c  01
#
#     date_of_creation
# 0         2016-01-27
# 67        2016-12-23
# 104       2018-08-22
# 114       2013-09-07
# 148       2015-09-14

# %%
playlist_coll = mydb['playlists'] # Select the playlists collection
playlist_dict = df_playlist_inserted.to_dict("records") # Transform the dataframe in a dict 
playlists_id = playlist_coll.insert_many(playlist_dict)
# Out:
# <pymongo.results.InsertManyResult object at 0x7f4eceea93c0>

# %%
df_songs = pd.DataFrame(df)
df_songs['artist_track'] = pd.DataFrame((df['artist'] + " " + df['track']))
df_songs = df_songs.drop_duplicates(subset=['artist_track']) # Take unique songs combination artist_trackname 
df_songs_inserted = df_songs.drop(['artist_track','playlist'],axis=1) # Drop useless columns
df_songs_inserted.head()
# Out:
#                             artist  \
# 0                   Elvis Costello
# 1  Elvis Costello  The Attractions
# 2                     Tiffany Page
# 3  Elvis Costello  The Attractions
# 4                   Elvis Costello
#
#                                               track
# 0                The Angels Wanna Wear My Red Shoes
# 1  Whats So Funny Bout Peace Love And Understanding
# 2                                  7 Years Too Late
# 3                             Accidents Will Happen
# 4                                            Alison

# %%
songs_coll = mydb['songs'] # Select the songs collection
song_dict = [{k:v for k,v in m.items() if pd.notnull(v)} for m in df_songs_inserted.to_dict(orient='records')]
songs_id = songs_coll.insert_many(song_dict) # returns the MongoDB ids for songs entities

# %%
df_unique_songs = list(df_songs['artist_track']) # Get unique artist_track values
df_unique_songs_id = songs_id.inserted_ids # Get unique songs_id values
zip_iterator = zip(df_unique_songs, df_unique_songs_id) 
key_value_dict = dict(zip_iterator) # Create a dict {artist_track: song_id}
df["song_id"] = df["artist_track"].map(key_value_dict) # Match artist_track with song_id
df.head()
# Out:
#                             artist  \
# 0                   Elvis Costello
# 1  Elvis Costello  The Attractions
# 2                     Tiffany Page
# 3  Elvis Costello  The Attractions
# 4                   Elvis Costello
#
#                                               track        playlist  \
# 0                The Angels Wanna Wear My Red Shoes  HARD ROCK 2010
# 1  Whats So Funny Bout Peace Love And Understanding  HARD ROCK 2010
# 2                                  7 Years Too Late  HARD ROCK 2010
# 3                             Accidents Will Happen  HARD ROCK 2010
# 4                                            Alison  HARD ROCK 2010
#
#                                         artist_track                   song_id
# 0  Elvis Costello The Angels Wanna Wear My Red Shoes  61eaa7a2f02e1050431fb76e
# 1  Elvis Costello  The Attractions Whats So Funny...  61eaa7a2f02e1050431fb76f
# 2                      Tiffany Page 7 Years Too Late  61eaa7a2f02e1050431fb770
# 3  Elvis Costello  The Attractions Accidents Will...  61eaa7a2f02e1050431fb771
# 4                              Elvis Costello Alison  61eaa7a2f02e1050431fb772

# %%
df_unique_playlist = list(df_playlist['playlist']) # Get unique playlist values
df_unique_playlist_id = playlists_id.inserted_ids # Get unique playlist_id values
zip_iterator = zip(df_unique_playlist, df_unique_playlist_id) 
key_value_dict = dict(zip_iterator) # Create a dict {playlist: playlist_id}
df["playlist_id"] = df["playlist"].map(key_value_dict) # Match playlist with playlist_id
df.head()
# Out:
#                             artist  \
# 0                   Elvis Costello
# 1  Elvis Costello  The Attractions
# 2                     Tiffany Page
# 3  Elvis Costello  The Attractions
# 4                   Elvis Costello
#
#                                               track        playlist  \
# 0                The Angels Wanna Wear My Red Shoes  HARD ROCK 2010
# 1  Whats So Funny Bout Peace Love And Understanding  HARD ROCK 2010
# 2                                  7 Years Too Late  HARD ROCK 2010
# 3                             Accidents Will Happen  HARD ROCK 2010
# 4                                            Alison  HARD ROCK 2010
#
#                                         artist_track  \
# 0  Elvis Costello The Angels Wanna Wear My Red Shoes
# 1  Elvis Costello  The Attractions Whats So Funny...
# 2                      Tiffany Page 7 Years Too Late
# 3  Elvis Costello  The Attractions Accidents Will...
# 4                              Elvis Costello Alison
#
#                     song_id               playlist_id
# 0  61eaa7a2f02e1050431fb76e  61eaa79ff02e1050431f95af
# 1  61eaa7a2f02e1050431fb76f  61eaa79ff02e1050431f95af
# 2  61eaa7a2f02e1050431fb770  61eaa79ff02e1050431f95af
# 3  61eaa7a2f02e1050431fb771  61eaa79ff02e1050431f95af
# 4  61eaa7a2f02e1050431fb772  61eaa79ff02e1050431f95af

# %%
# Get the list of songs contained in each playlist
group = df.drop_duplicates(['playlist_id','song_id']).reindex(columns=['song_id','artist','track','album','date','playlist_id']).rename(columns={"song_id": "_id"}).groupby('playlist_id')
series = group.apply(lambda x: [{k:v for k,v in m.items() if pd.notnull(v)} for m in x.to_dict(orient='records')])
df_playlist_song = pd.DataFrame({
    'playlist_id': series.index,
    'songs_in_playlist': series.values
})
df_playlist_song['songs_in_playlist'][1]
# Out:
# [{'_id': ObjectId('61eaa7a2f02e1050431fb7b1'),
#   'artist': 'Noah And The Whale',
#   'track': '5 Years Time',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b2'),
#   'artist': 'Noel Gallaghers High Flying Birds',
#   'track': 'AKA What A Life',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b3'),
#   'artist': 'Pearl Jam',
#   'track': 'Alive',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b4'),
#   'artist': 'Tom Petty And The Heartbreakers',
#   'track': 'American Girl',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b5'),
#   'artist': 'Bruce Springsteen',
#   'track': 'Atlantic City',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b6'),
#   'artist': 'Madness',
#   'track': 'Baggy Trousers',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b7'),
#   'artist': 'Pearl Jam',
#   'track': 'Black',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b8'),
#   'artist': 'Bruce Springsteen',
#   'track': 'Born to Run',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b9'),
#   'artist': 'Spector',
#   'track': 'Chevy Thunder',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ba'),
#   'artist': 'Miles Kane',
#   'track': 'Come Closer',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7bb'),
#   'artist': 'Bruce Springsteen',
#   'track': 'Death To My Hometown',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7bc'),
#   'artist': 'Pearl Jam',
#   'track': 'Even Flow',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7bd'),
#   'artist': 'Noel Gallaghers High Flying Birds',
#   'track': 'Everybodys On the Run',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7be'),
#   'artist': 'Miles Kane',
#   'track': 'First of My Kind',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7bf'),
#   'artist': 'Tom Petty',
#   'track': 'Free Fallin',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c0'),
#   'artist': 'Biffy Clyro',
#   'track': 'God  Satan',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c1'),
#   'artist': 'Elbow',
#   'track': 'Grounds For Divorce',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c2'),
#   'artist': 'Madness',
#   'track': 'House Of Fun',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c3'),
#   'artist': 'Miles Kane',
#   'track': 'Inhaler',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c4'),
#   'artist': 'Madness',
#   'track': 'It Must Be Love',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c5'),
#   'artist': 'Pearl Jam',
#   'track': 'Just Breathe',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c6'),
#   'artist': 'Noah And The Whale',
#   'track': 'LIFEGOESON',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c7'),
#   'artist': 'Tom Petty And The Heartbreakers',
#   'track': 'Learning To Fly',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c8'),
#   'artist': 'Oasis',
#   'track': 'Little By Little',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7c9'),
#   'artist': 'Biffy Clyro',
#   'track': 'Many Of Horror',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ca'),
#   'artist': 'Biffy Clyro',
#   'track': 'Mountains',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7cb'),
#   'artist': 'Elbow',
#   'track': 'One Day Like This',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7cc'),
#   'artist': 'Madness',
#   'track': 'Our House',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7cd'),
#   'artist': 'Bruce Springsteen',
#   'track': 'Queen Of The Supermarket',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ce'),
#   'artist': 'Thunderclap Newman',
#   'track': 'Something In The Air  Single Version',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7cf'),
#   'artist': 'Biffy Clyro',
#   'track': 'The Captain',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7d0'),
#   'artist': 'Thunderclap Newman',
#   'track': 'The Reason',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7d1'),
#   'artist': 'Bruce Springsteen',
#   'track': 'The River',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7d2'),
#   'artist': 'Bruce Springsteen',
#   'track': 'We Take Care Of Our Own',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7d3'),
#   'artist': 'Bruce Springsteen',
#   'track': 'Wrecking Ball',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7d4'),
#   'artist': 'Pearl Jam',
#   'track': 'Yellow Ledbetter',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7d5'),
#   'artist': 'Elbow',
#   'track': 'the birds',
#   'playlist_id': ObjectId('61eaa79ff02e1050431f95b0')}]

# %%
def remove_song_values(x):
    for song in x:
        del song['playlist_id']
    return x

# %%
df_playlist_song['songs_in_playlist'] = df_playlist_song['songs_in_playlist'].apply(remove_song_values) #Remove

# %%
df_playlist_song['songs_in_playlist'][0]
# Out:
# [{'_id': ObjectId('61eaa7a2f02e1050431fb76e'),
#   'artist': 'Elvis Costello',
#   'track': 'The Angels Wanna Wear My Red Shoes'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb76f'),
#   'artist': 'Elvis Costello  The Attractions',
#   'track': 'Whats So Funny Bout Peace Love And Understanding'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb770'),
#   'artist': 'Tiffany Page',
#   'track': '7 Years Too Late'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb771'),
#   'artist': 'Elvis Costello  The Attractions',
#   'track': 'Accidents Will Happen'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb772'),
#   'artist': 'Elvis Costello',
#   'track': 'Alison'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb773'),
#   'artist': 'Lissie',
#   'track': 'All Be Okay'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb774'),
#   'artist': 'Paul McCartney',
#   'track': 'Band On The Run'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb775'),
#   'artist': 'Joe Echo',
#   'track': 'Beautiful'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb776'),
#   'artist': 'Paul McCartney',
#   'track': 'Blackbird  Live at CitiField NYC  Digital Audio'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb777'),
#   'artist': 'Lissie',
#   'track': 'Bright Side'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb778'),
#   'artist': 'The Breakers',
#   'track': 'Dance The GoGo'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb779'),
#   'artist': 'Paul McCartney',
#   'track': 'Dance Tonight'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb77a'),
#   'artist': 'The Coronas',
#   'track': 'Decision Time'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb77b'),
#   'artist': 'Crowded House',
#   'track': 'Dont Dream Its Over'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb77c'),
#   'artist': 'Lissie',
#   'track': 'Everywhere I Go'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb77d'),
#   'artist': 'Crowded House',
#   'track': 'Fall At Your Feet'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb77e'),
#   'artist': 'Crowded House',
#   'track': 'Four Seasons In One Day'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb77f'),
#   'artist': 'Joshua Radin',
#   'track': 'Friend Like You'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb780'),
#   'artist': 'The Breakers',
#   'track': 'Get Lost Get High Get Sick'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb781'),
#   'artist': 'Cocktail Slippers',
#   'track': 'Goodtimes'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb782'),
#   'artist': 'Crosby Stills  Nash',
#   'track': 'Helplessly Hoping'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb783'),
#   'artist': 'Lissie',
#   'track': 'Here Before'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb784'),
#   'artist': 'Cocktail Slippers',
#   'track': 'Here We Go'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb785'),
#   'artist': 'Tiffany Page',
#   'track': 'I Am The Blaze'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb786'),
#   'artist': 'The Len Price 3',
#   'track': 'I Dont Believe You'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb787'),
#   'artist': 'Joshua Radin',
#   'track': 'Id Rather Be With You Radio Edit'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb788'),
#   'artist': 'The Len Price 3',
#   'track': 'If You Live Round Here'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb789'),
#   'artist': 'Lissie',
#   'track': 'In Sleep'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb78a'),
#   'artist': 'Cocktail Slippers',
#   'track': 'In The City'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb78b'),
#   'artist': 'Joe Echo',
#   'track': 'In You Are All The Stories'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb78c'),
#   'artist': 'The Len Price 3',
#   'track': 'Keep Your Eyes On Me'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb78d'),
#   'artist': 'Joe Echo',
#   'track': 'Lie To Me'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb78e'),
#   'artist': 'Lissie',
#   'track': 'Little Lovin'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb78f'),
#   'artist': 'Paul McCartney',
#   'track': 'Live And Let Die'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb790'),
#   'artist': 'The Len Price 3',
#   'track': 'Man Who Used To Be'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb791'),
#   'artist': 'Cocktail Slippers',
#   'track': 'Mastermind'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb792'),
#   'artist': 'Crowded House',
#   'track': 'Nobody Wants To'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb793'),
#   'artist': 'Crowded House',
#   'track': 'Not The Girl You Think You Are'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb794'),
#   'artist': 'Lissie',
#   'track': 'Oh Mississippi'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb795'),
#   'artist': 'Elvis Costello  The Attractions',
#   'track': 'Olivers Army'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb796'),
#   'artist': 'Joe Echo',
#   'track': 'On All My Sundays  Liam Shachar Radio Mix'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb797'),
#   'artist': 'Joe Echo',
#   'track': 'On All My Sundays  Liam Shachar Remix'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb798'),
#   'artist': 'Joshua Radin',
#   'track': 'Only You'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb799'),
#   'artist': 'Tiffany Page',
#   'track': 'Out Of My Mind'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb79a'),
#   'artist': 'Joe Echo',
#   'track': 'Personal Alcatraz'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb79b'),
#   'artist': 'Joe Echo',
#   'track': 'Phoenix In Dynamite Sky'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb79c'),
#   'artist': 'The Len Price 3',
#   'track': 'Pictures'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb79d'),
#   'artist': 'The Len Price 3',
#   'track': 'Sailors Sweetheart'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb79e'),
#   'artist': 'The Coronas',
#   'track': 'San Diego Song'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb79f'),
#   'artist': 'Cocktail Slippers',
#   'track': 'Sentenced To Love'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a0'),
#   'artist': 'Crosby Stills  Nash',
#   'track': 'Southern Cross'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a1'),
#   'artist': 'Cocktail Slippers',
#   'track': 'St Valentines Day Massacre'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a2'),
#   'artist': 'Joe Echo',
#   'track': 'The Darker It Gets'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a3'),
#   'artist': 'The Len Price 3',
#   'track': 'The Girl Who Became a Machine'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a4'),
#   'artist': 'Joe Echo',
#   'track': 'The World It Still Revolves  Garage Demo'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a5'),
#   'artist': 'Joe Echo',
#   'track': 'This Is The World We Live In'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a6'),
#   'artist': 'Elvis Costello',
#   'track': 'Tramp The Dirt Down'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a7'),
#   'artist': 'The Breakers',
#   'track': 'Tried So Hard'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a8'),
#   'artist': 'Crosby Stills  Nash',
#   'track': 'Unequal Love'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7a9'),
#   'artist': 'Tiffany Page',
#   'track': 'Walk Away Slow'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7aa'),
#   'artist': 'Crowded House',
#   'track': 'Weather With You'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ab'),
#   'artist': 'Lissie',
#   'track': 'Wedding Bells'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ac'),
#   'artist': 'Joshua Radin',
#   'track': 'What If You'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ad'),
#   'artist': 'Joe Echo',
#   'track': 'What Skin Is All About'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7ae'),
#   'artist': 'Paul McCartney  Eric Clapton',
#   'track': 'While My Guitar Weeps'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7af'),
#   'artist': 'Joshua Radin',
#   'track': 'Winter'},
#  {'_id': ObjectId('61eaa7a2f02e1050431fb7b0'),
#   'artist': 'Cocktail Slippers',
#   'track': 'You Do Run'}]

# %%
# Add the column of embedded documents to the principal df and save it as "df_playlist_embedded"
df_playlist_embedded = (pd.merge(df.drop_duplicates(subset=['playlist_id']), df_playlist_song, on='playlist_id'))

# %%
def insert_playlist_embedded(playlist_id,embedded_doc):
    playlist_coll.update_one(
        {"_id" : playlist_id}, 
        { "$set": { 'songs_in_playlist': embedded_doc}}
    )

# %%
# %%capture
df_playlist_embedded.apply(lambda x: insert_playlist_embedded(x.playlist_id, x.songs_in_playlist,), axis=1)

# %%
# Get the list of playlists in which a song is contained, for each song
group = df.drop_duplicates(['playlist_id','song_id']).reindex(columns=['playlist_id','playlist','song_id']).rename(columns={"playlist_id": "_id", "playlist":"name"}).groupby('song_id')
series = group.apply(lambda x: x.to_dict('records'))
df_song_playlist = pd.DataFrame({
    'song_id': series.index,
    'playlists_that_contains_it': series.values
})
df_song_playlist.head()
# Out:
#                     song_id                         playlists_that_contains_it
# 0  61eaa7a2f02e1050431fb76e  [{'_id': 61eaa79ff02e1050431f95af, 'name': 'HA...
# 1  61eaa7a2f02e1050431fb76f  [{'_id': 61eaa79ff02e1050431f95af, 'name': 'HA...
# 2  61eaa7a2f02e1050431fb770  [{'_id': 61eaa79ff02e1050431f95af, 'name': 'HA...
# 3  61eaa7a2f02e1050431fb771  [{'_id': 61eaa79ff02e1050431f95af, 'name': 'HA...
# 4  61eaa7a2f02e1050431fb772  [{'_id': 61eaa79ff02e1050431f95af, 'name': 'HA...

# %%
#Remove values not needed 
def remove_playlist_values(x):
    for playlist in x:
        del playlist['song_id']
    return x

# %%
#Remove values not needed
df_song_playlist['playlists_that_contains_it'] = df_song_playlist['playlists_that_contains_it'].apply(remove_playlist_values)

# %%
df_song_playlist['playlists_that_contains_it'][0]
# Out:
# [{'_id': ObjectId('61eaa79ff02e1050431f95af'), 'name': 'HARD ROCK 2010'},
#  {'_id': ObjectId('61eaa79ff02e1050431f95b9'), 'name': 'Starred'}]

# %%
# Add the column of embedded documents to the principal df and save it as "df_songs_embedded"
df_songs_embedded = (pd.merge(df.drop_duplicates(subset=['song_id']), df_song_playlist, on='song_id'))

# %%
def insert_songs_embedded(song_id,embedded_doc):
    songs_coll.update_one(
        {"_id" : song_id}, 
        { "$set": { 'playlists': embedded_doc } }
    )

# %%
# %%capture
df_songs_embedded.apply(lambda x: insert_songs_embedded(x.song_id, x.playlists_that_contains_it), axis=1)

# %%
users_coll = mydb['users'] # Select the users collection

# %%
from random import randint
users = users_coll.find()
user = users[randint(0, 13000)]
print(user)
# Out:
# {'_id': ObjectId('61cc6cbb3bd8fb88c6629f30'), 'username': 'kike79', 'dateOfBirth': datetime.datetime(1955, 3, 16, 0, 0), 'dateOfCreation': datetime.datetime(2014, 6, 13, 0, 0), 'isAdmin': False, 'password': 'MgUoWPhDPNEkWEQI'}

# %%
def insert_creator_in_playlist(playlist_id, playlist_name):
    user = users[randint(0, 13000)]
    playlist_coll.update_one(
        {"_id" : playlist_id}, 
        { "$set": { 'creator': {'_id': user['_id'], 'username': user['username']}} }
    )
    users_coll.update_one(
        {"_id" : user['_id']}, 
        { "$push": { 'createdPlaylists': {'_id': playlist_id, 'name': playlist_name}} }
    )

# %%
df_playlist_embedded.apply(lambda x: insert_creator_in_playlist(x.playlist_id, x.playlist), axis=1)
df_playlist_embedded.head()
# Out:
#                artist                               track        playlist  \
# 0      Elvis Costello  The Angels Wanna Wear My Red Shoes  HARD ROCK 2010
# 1  Noah And The Whale                        5 Years Time        IOW 2012
# 2                2080                                1 Up            2080
# 3                C418                               Alive            C418
# 4                C418                           0x10c  01       Chill out
#
#                                         artist_track  \
# 0  Elvis Costello The Angels Wanna Wear My Red Shoes
# 1                    Noah And The Whale 5 Years Time
# 2                                          2080 1 Up
# 3                                         C418 Alive
# 4                                     C418 0x10c  01
#
#                     song_id               playlist_id  \
# 0  61eaa7a2f02e1050431fb76e  61eaa79ff02e1050431f95af
# 1  61eaa7a2f02e1050431fb7b1  61eaa79ff02e1050431f95b0
# 2  61eaa7a2f02e1050431fb7d6  61eaa79ff02e1050431f95b1
# 3  61eaa7a2f02e1050431fb7e0  61eaa79ff02e1050431f95b2
# 4  61eaa7a2f02e1050431fb802  61eaa79ff02e1050431f95b3
#
#                                    songs_in_playlist
# 0  [{'_id': 61eaa7a2f02e1050431fb76e, 'artist': '...
# 1  [{'_id': 61eaa7a2f02e1050431fb7b1, 'artist': '...
# 2  [{'_id': 61eaa7a2f02e1050431fb7d6, 'artist': '...
# 3  [{'_id': 61eaa7a2f02e1050431fb7e0, 'artist': '...
# 4  [{'_id': 61eaa7a2f02e1050431fb802, 'artist': '...

# %%
playlist_coll.update_many( {}, { "$rename": { 
    "playlist": "name",
    "date_of_creation": "creationDate",
    "songs_in_playlist": "songs"
} } )

# %%
playlist_csv = df.drop_duplicates(subset=['playlist_id']).drop(['artist','track','artist_track'],axis=1).reindex(columns=['playlist_id','playlist'])
playlist_csv['playlist'] = playlist_csv['playlist'].apply(lambda x: str(x).replace('"',"'"))
playlist_csv.head()
# Out:
#                   playlist_id        playlist
# 0    61eaa79ff02e1050431f95af  HARD ROCK 2010
# 67   61eaa79ff02e1050431f95b0        IOW 2012
# 104  61eaa79ff02e1050431f95b1            2080
# 114  61eaa79ff02e1050431f95b2            C418
# 148  61eaa79ff02e1050431f95b3       Chill out

# %%
songs_csv = df.drop_duplicates(subset=['song_id']).drop(['playlist','artist_track','playlist_id'],axis=1).reindex(columns=['track','song_id','artist'])
songs_csv['track'] = songs_csv['track'].apply(lambda x: str(x).replace('"',"'"))
songs_csv['artist'] = songs_csv['artist'].apply(lambda x: str(x).replace('"',"'"))
songs_csv.head()
# Out:
#                                               track                   song_id  \
# 0                The Angels Wanna Wear My Red Shoes  61eaa7a2f02e1050431fb76e
# 1  Whats So Funny Bout Peace Love And Understanding  61eaa7a2f02e1050431fb76f
# 2                                  7 Years Too Late  61eaa7a2f02e1050431fb770
# 3                             Accidents Will Happen  61eaa7a2f02e1050431fb771
# 4                                            Alison  61eaa7a2f02e1050431fb772
#
#                             artist
# 0                   Elvis Costello
# 1  Elvis Costello  The Attractions
# 2                     Tiffany Page
# 3  Elvis Costello  The Attractions
# 4                   Elvis Costello

# %%
users = users_coll.find()
users_csv = pd.DataFrame(data=users)
users_csv = users_csv.drop(['dateOfBirth', 'dateOfCreation', 'isAdmin', 'password', 'createdPlaylists'], axis=1)
users_csv.head()
# Out:
#                         _id          username
# 0  61cc6cbb3bd8fb88c6628b8b            DeeCee
# 1  61cc6cbb3bd8fb88c6628b8c       CySorcerorD
# 2  61cc6cbb3bd8fb88c6628b8d             guesg
# 3  61cc6cbb3bd8fb88c6628b8e  SpaceGhostBenoit
# 4  61cc6cbb3bd8fb88c6628b8f       Meandmylife

# %%
users_csv['n_playlist_followed'] = [ random.randint(0,50)  for k in users_csv._id] 
users_csv['n_user_followed'] = [ random.randint(0,20)  for k in users_csv._id]
users_csv.head()
# Out:
#                         _id          username  n_playlist_followed  \
# 0  61cc6cbb3bd8fb88c6628b8b            DeeCee                   21
# 1  61cc6cbb3bd8fb88c6628b8c       CySorcerorD                   23
# 2  61cc6cbb3bd8fb88c6628b8d             guesg                   36
# 3  61cc6cbb3bd8fb88c6628b8e  SpaceGhostBenoit                   17
# 4  61cc6cbb3bd8fb88c6628b8f       Meandmylife                   48
#
#    n_user_followed
# 0                0
# 1                2
# 2               17
# 3               15
# 4               17

# %%
from neo4j import GraphDatabase

# %%
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver(self.__uri, auth=(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
conn = Neo4jConnection(uri="neo4j://localhost:7687/browser/",user = "neo4j", pwd = "root") # Neo4j connection

# %%
# INSERT PLAYLIST NODES

for index, row in playlist_csv.iterrows():
    query_string = f'''
        CREATE (:Playlist {{name: "{row.playlist}", id: "{row.playlist_id}" }})
    '''
    conn.query(query_string,db='neo4j')

# %%
# INSERT USER NODES

for index, row in users_csv.iterrows():
    query_string = f'''
        CREATE (:User {{name: "{row.username}", id: "{row._id}" }})
    '''
    conn.query(query_string,db='neo4j')

# %%
# CREATE RELATIONSHIP
# User ->: LIKES -> Playlist

for index, row in users_csv.iterrows():
    for index2, row2 in playlist_csv.sample(row.n_playlist_followed).iterrows():
        query_string = f'''
        MATCH (u:User) WHERE u.id = "{row._id}"
        MATCH (p:Playlist) WHERE p.id = "{row2.playlist_id}"
        CREATE (u)-[:LIKES]->(p)
        '''

        conn.query(query_string,db='neo4j')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [34], in Neo4jConnection.query(self, query, db)
#      22     session = self.__driver.session(database=db) if db is not None else self.__driver.session()
# ---> 23     response = list(session.run(query))
#      24 except Exception as e:
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/work/simple.py:215, in Session.run(self, query, parameters, **kwparameters)
#     211 self._autoResult = Result(
#     212     cx, hydrant, self._config.fetch_size, self._result_closed,
#     213     self._result_error
#     214 )
# --> 215 self._autoResult._run(
#     216     query, parameters, self._config.database,
#     217     self._config.impersonated_user, self._config.default_access_mode,
#     218     self._bookmarks, **kwparameters
#     219 )
#     221 return self._autoResult
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/work/result.py:114, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, **kwparameters)
#     113 self._connection.send_all()
# --> 114 self._attach()
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/work/result.py:203, in Result._attach(self)
#     202 while self._attached is False:
# --> 203     self._connection.fetch_message()
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_common.py:167, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     166 try:
# --> 167     func(*args, **kwargs)
#     168 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_bolt4.py:286, in Bolt4x0.fetch_message(self)
#     285 # Receive exactly one message
# --> 286 details, summary_signature, summary_metadata = next(self.inbox)
#     288 if details:
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_common.py:81, in Inbox.__next__(self)
#      80 def __next__(self):
# ---> 81     tag, fields = self.pop()
#      82     if tag == b"\x71":
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_common.py:75, in MessageInbox.pop(self)
#      74 def pop(self):
# ---> 75     return next(self._messages)
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_common.py:55, in MessageInbox._yield_messages(self, sock)
#      53 while chunk_size == 0:
#      54     # Determine the chunk size and skip noop
# ---> 55     buffer.receive(sock, 2)
#      56     chunk_size = buffer.pop_u16()
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/packstream.py:482, in UnpackableBuffer.receive(self, sock, n_bytes)
#     481 while self.used < end:
# --> 482     n = sock.recv_into(view[self.used:end], end - self.used)
#     483     if n == 0:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# StopIteration                             Traceback (most recent call last)
# Input In [38], in <module>
#       5 for index2, row2 in playlist_csv.sample(row.n_playlist_followed).iterrows():
#       6     query_string = f'''
#       7     MATCH (u:User) WHERE u.id = "{row._id}"
#       8     MATCH (p:Playlist) WHERE p.id = "{row2.playlist_id}"
#       9     CREATE (u)-[:LIKES]->(p)
#      10     '''
# ---> 12     conn.query(query_string,db='neo4j')
#
# Input In [34], in Neo4jConnection.query(self, query, db)
#      26 finally:
#      27     if session is not None:
# ---> 28         session.close()
#      29 return response
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/work/simple.py:150, in Session.close(self)
#     148     if self._connection:
#     149         self._connection.send_all()
# --> 150         self._connection.fetch_all()
#     151         # TODO: Investigate potential non graceful close states
#     152 except Neo4jError:
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/__init__.py:535, in Bolt.fetch_all(self)
#     533 response = self.responses[0]
#     534 while not response.complete:
# --> 535     detail_delta, summary_delta = self.fetch_message()
#     536     detail_count += detail_delta
#     537     summary_count += summary_delta
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_bolt4.py:286, in Bolt4x0.fetch_message(self)
#     283     return 0, 0
#     285 # Receive exactly one message
# --> 286 details, summary_signature, summary_metadata = next(self.inbox)
#     288 if details:
#     289     log.debug("[#%04X]  S: RECORD * %d", self.local_port, len(details))  # Do not log any data
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_common.py:81, in Inbox.__next__(self)
#      80 def __next__(self):
# ---> 81     tag, fields = self.pop()
#      82     if tag == b"\x71":
#      83         return fields, None, None
#
# File /var/data/python/lib/python3.9/site-packages/neo4j/io/_common.py:75, in MessageInbox.pop(self)
#      74 def pop(self):
# ---> 75     return next(self._messages)
#
# StopIteration:

# %%
# INSERT SONG NODES 

for index, row in songs_csv.iterrows():
    query_string = ''
    query_string = f'''
        CREATE (:Song {{
        id: "{row.song_id}",
        track: "{row.track}",
        artist: "{row.artist}"
        }})
    '''  
    conn.query(query_string,db='neo4j')

# %%
# CREATE RELATIONSHIP
# User ->: FOLLOWS -> User

for index, row in users_csv.iterrows():
    for index2, row2 in users_csv.sample(row.n_user_followed).iterrows():
        query_string = f'''
        MATCH (u:User) WHERE u.id = "{row._id}"
        MATCH (u_2:User) WHERE u_2.id = "{row2._id}"
        CREATE (u)-[:FOLLOWS]->(u_2)
        '''
        #print(query_string)
        conn.query(query_string,db='neo4j')

# %%
# Delete, if exists, self-reletionships from neo4j graph
query_string = f'''
        MATCH (a:User)-[rel:FOLLOWS]->(a2)
        WHERE a.id = a2.id
        DELETE rel;
        '''
conn.query(query_string,db='neo4j')
# Out:
# []
