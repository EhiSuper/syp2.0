# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup, Tag
import re
from multiprocessing.dummy import Pool as ThreadPool

# %%
df = pd.read_csv('dataframe.csv')

# %%
# Get only unique artist-tracks -> Don't scrape two or more times a song
df_no_dupl = df.drop_duplicates(subset = ["artist_track"])

# %%
print(df.shape)
# Out:
# (257717, 5)

# %%
print(df_no_dupl.shape)
# Out:
# (180961, 5)

# %%
def get_text_with_br(tag, result=''):
    
    for x in tag.contents:
        if isinstance(x, Tag):  # check if content is a tag
            if x.name == 'br':  # if tag is <br> append it as string
                result += str(x)
            else:  # for any other tag, recurse
                result = get_text_with_br(x, result)
        else:  # if content is NavigableString (string), append
            result += x
    
    return result

def scrape_info(artist_track):

    print(artist_track)
    result = ''
    url  = "https://genius.com/" + artist_track
    try:
        page = requests.get(url)
    except:
        return "NA", "NA", "NA",[] 
    
    #Check if the genius page exists 
    if page.status_code != 200:
        return "NA", "NA", "NA",[]    
    
    html = BeautifulSoup(page.text, 'html.parser') # Take page's html
    
    song_id = html.find('meta', {"property": "twitter:app:url:iphone"})['content'].replace('genius://songs/','')
    
    # Get album
    try:
        album = html.find('a', {"href": "#primary-album"}).get_text() 
    except:
        album = "NA"
    
    # Get date
    try:
        date = "NA"
        container = html.find_all('div', {"class": "HeaderMetadata__Section-sc-1p42fnf-7"})
        for element in container:
            if "Release" in element.get_text():
                date = element.get_text().replace("Release Date","")
    except:
        pass
        
    # Get lyrics
    try:
        lyrics = html.find('div', {"id": "annotation-portal-target"})
        result = get_text_with_br(lyrics).replace('<br/>','\n')
        result = result.replace("EmbedShare URLCopyEmbedCopyCancelHow to Format Lyrics:Type out all lyrics, even if it’s a chorus that’s repeated throughout the songThe Section Header button breaks up song sections. Highlight the text then click the linkUse Bold and Italics only to distinguish between different singers in the same verse.E.g. “Verse 1: Kanye West, Jay-Z, Both”Capitalize each lineTo move an annotation to different lyrics in the song, use the [...] menu to switch to referent editing mode","")
    except:
        result = "NA"
        
        
    # Get comments
    
    url  = "https://genius.com/api/songs/" + song_id + "/comments"
    try:
        comments_page = requests.get(url).json()
    except:
        return album, date, result,[] 
    comments = comments_page['response']['comments']
    #print(comments)
    comment_list = []
    
    for comment in comments:
        if (comment['anonymous_author'] == None):
            comment_author = comment['author']['name']
            comment_date = comment['created_at']
            comment_text = comment['body']['dom']['children']
    
            comment_list.append((comment_author,comment_date,comment_text,artist_track))    
    
    return album,date,result, comment_list

# %%
songs_info = []
comments_info = []

def scrape(artist_track):
    album,date,lyrics,comments = scrape_info(artist_track)
    songs_info.append((album,date,lyrics,artist_track))
    comments_info.append(comments)

# %%
# Pool of thread used to scrape faster all the songs

p = ThreadPool(50)
p.map(scrape,df_no_dupl.artist_track)
p.terminate()
p.join()

# %% [markdown]
# # MONGODB

# %%
# Getting all song names 

artists_tracks = []
for song in songs_info:
    artists_tracks.append(song[3])

# %%
df = df[df['artist_track'].isin(artists_tracks)] # Checking which song_names have been scraped

# %%
print(df.shape)
# Out:
# (257717, 5)

# %%
df_songs_info = pd.DataFrame(songs_info,columns=['album','date','lyrics','artist_track']) # Create the dataframe for mongoDB info

# %%
df = pd.merge(df,df_songs_info,on='artist_track') # Merge the old info with the info scraped

# %%
df.drop_duplicates(subset=['artist_track']).head(30)
# Out:
#                              user_id                artist  \
# 0   9cc0cfd4d7d7885102480dd99e7a90d6    Crosby Stills Nash
# 1   07f0fc3be95dcd878966b1f9572ff670                  C418
# 2   07f0fc3be95dcd878966b1f9572ff670                  C418
# 3   07f0fc3be95dcd878966b1f9572ff670         Pretty Lights
# 4   07f0fc3be95dcd878966b1f9572ff670  Ludwig van Beethoven
# 5   07f0fc3be95dcd878966b1f9572ff670               Ratatat
# 7   07f0fc3be95dcd878966b1f9572ff670           The Prodigy
# 10  07f0fc3be95dcd878966b1f9572ff670              Skrillex
# 24  07f0fc3be95dcd878966b1f9572ff670            Shaka Ponk
# 26  07f0fc3be95dcd878966b1f9572ff670       Dschinghis Khan
# 27  07f0fc3be95dcd878966b1f9572ff670             Daft Punk
# 29  07f0fc3be95dcd878966b1f9572ff670           Kenji Kawai
# 30  07f0fc3be95dcd878966b1f9572ff670           Murray Gold
# 32  07f0fc3be95dcd878966b1f9572ff670      Zalza vs Scattle
# 33  07f0fc3be95dcd878966b1f9572ff670        Our Last Night
# 35  07f0fc3be95dcd878966b1f9572ff670            Sex BobOmb
# 36  07f0fc3be95dcd878966b1f9572ff670            Portishead
# 46  07f0fc3be95dcd878966b1f9572ff670              Bon Jovi
# 57  07f0fc3be95dcd878966b1f9572ff670                 Creed
# 64  07f0fc3be95dcd878966b1f9572ff670            Pink Floyd
# 70  07f0fc3be95dcd878966b1f9572ff670               Jurojin
# 71  07f0fc3be95dcd878966b1f9572ff670         Birdy Nam Nam
# 73  944c80d26922ae634d6ce445b1fdff7f       Various Artists
# 74  944c80d26922ae634d6ce445b1fdff7f                 McFly
# 75  944c80d26922ae634d6ce445b1fdff7f        Elise Lieberth
# 76  944c80d26922ae634d6ce445b1fdff7f       The Courteeners
# 77  944c80d26922ae634d6ce445b1fdff7f            Ben Howard
# 83  944c80d26922ae634d6ce445b1fdff7f        Flogging Molly
# 87  944c80d26922ae634d6ce445b1fdff7f             The Twang
# 89  944c80d26922ae634d6ce445b1fdff7f          Lennon Maisy
#
#                                                 track        playlist  \
# 0                                   Helplessly Hoping  HARD ROCK 2010
# 1                                               Chris            C418
# 2                                            Équinoxe            C418
# 3                                    I Know the Truth       Chill out
# 4   Sonata No 23 In F Minor Op 57 Appassionata Ass...       Classique
# 5                                             Kennedy         Electro
# 7                             Take Me To The Hospital         Electro
# 10                               Bangarang feat Sirah          Soirée
# 24                                          Lets Bang          Soirée
# 26                                Moskau Long Version          Soirée
# 27                                             Finale         Starred
# 29                       M01 Making of Cyborg Chant I         Starred
# 30                         Voyage of the Damned Suite         Starred
# 32                                              Xycle         Starred
# 33                                               Fate   Work playlist
# 35                                      Garbage Truck   Work playlist
# 36                                          Glory Box   Work playlist
# 46                                        Its My Life   Work playlist
# 57                                    One Last Breath   Work playlist
# 64                    Shine On You Crazy Diamond Live   Work playlist
# 70                                          The Scars   Work playlist
# 71                             Trans Boulogne Express   Work playlist
# 73                              I Fancy Laura Marling  2014 beginning
# 74                  Love Is On The Radio Mr Mrs F Mix  2014 beginning
# 75                                  She Keeps Me Warm  2014 beginning
# 76                                 That Kiss Acoustic  2014 beginning
# 77                                           Gracious        Gracious
# 83                   If I Ever Leave This World Alive          JOOTDR
# 87                                      Barney Rubble         Starred
# 89                               Call Your Girlfriend         Starred
#
#                                          artist_track  \
# 0         Crosby-Stills-Nash-Helplessly-Hoping-lyrics
# 1                                   C418-Chris-lyrics
# 2                                C418-Équinoxe-lyrics
# 3               Pretty-Lights-I-Know-the-Truth-lyrics
# 4   Ludwig-van-Beethoven-Sonata-No-23-In-F-Minor-O...
# 5                              Ratatat-Kennedy-lyrics
# 7          The-Prodigy-Take-Me-To-The-Hospital-lyrics
# 10               Skrillex-Bangarang-feat-Sirah-lyrics
# 24                        Shaka-Ponk-Lets-Bang-lyrics
# 26         Dschinghis-Khan-Moskau-Long-Version-lyrics
# 27                            Daft-Punk-Finale-lyrics
# 29    Kenji-Kawai-M01-Making-of-Cyborg-Chant-I-lyrics
# 30      Murray-Gold-Voyage-of-the-Damned-Suite-lyrics
# 32                      Zalza-vs-Scattle-Xycle-lyrics
# 33                         Our-Last-Night-Fate-lyrics
# 35                    Sex-BobOmb-Garbage-Truck-lyrics
# 36                        Portishead-Glory-Box-lyrics
# 46                        Bon-Jovi-Its-My-Life-lyrics
# 57                       Creed-One-Last-Breath-lyrics
# 64  Pink-Floyd-Shine-On-You-Crazy-Diamond-Live-lyrics
# 70                           Jurojin-The-Scars-lyrics
# 71        Birdy-Nam-Nam-Trans-Boulogne-Express-lyrics
# 73       Various-Artists-I-Fancy-Laura-Marling-lyrics
# 74     McFly-Love-Is-On-The-Radio-Mr-Mrs-F-Mix-lyrics
# 75            Elise-Lieberth-She-Keeps-Me-Warm-lyrics
# 76          The-Courteeners-That-Kiss-Acoustic-lyrics
# 77                         Ben-Howard-Gracious-lyrics
# 83  Flogging-Molly-If-I-Ever-Leave-This-World-Aliv...
# 87                     The-Twang-Barney-Rubble-lyrics
# 89           Lennon-Maisy-Call-Your-Girlfriend-lyrics
#
#                                                 album                date  \
# 0                                                  NA                  NA
# 1                           Minecraft - Volume Alpha        March 4, 2011
# 2                                                  NA                  NA
# 3                                                  NA                  NA
# 4                                                  NA                  NA
# 5                                           Classics      August 22, 2006
# 7                                  Invaders Must Die      August 31, 2009
# 10                                                 NA                  NA
# 24                    The Geeks And The Jerkin’ Sock         June 6, 2011
# 26                                           7 Leben                 1979
# 27  TRON: Legacy (Original Motion Picture Soundtra...    December 3, 2010
# 29                                                 NA                  NA
# 30  Doctor Who: Series 4 (Original Television Soun...    October 31, 2008
# 32                                                 NA                  NA
# 33                                  Age of Ignorance      August 21, 2012
# 35                                                 NA                  NA
# 36                                             Dummy    December 20, 1994
# 46                                             Crush         May 23, 2000
# 57                                         Weathered       April 15, 2002
# 64                                                 NA                  NA
# 70                        The Living Measure of Time                   NA
# 71                     Manual for Successful Rioting                   NA
# 73                                                 NA                  NA
# 74                                                 NA                  NA
# 75                                                 NA                  NA
# 76                                                 NA                  NA
# 77                            Every Kingdom (Deluxe)   September 30, 2011
# 83                       Alive Behind the Green Door                 1997
# 87                                 Jewellery Quarter        July 27, 2009
# 89                                                 NA                  NA
#
#                                                lyrics
# 0                                                  NA
# 1                        This song is an instrumental
# 2                                                  NA
# 3   I'm too blind\nI'm too blind.....to see the li...
# 4                                                  NA
# 5                        This song is an instrumental
# 7   [Intro]\nTake me to the...\nTake me to the...\...
# 10                                                 NA
# 24  Let's Bang\nHey Sugar Hey\n\n[Couplet 1]\nSatu...
# 26  Moskau\nFremd und geheimnisvoll\nTürme aus rot...
# 27                       This song is an instrumental
# 29                                                 NA
# 30                       This song is an instrumental
# 32                                                 NA
# 33  [Verse 1]\nAm I meant to be something?\nIs thi...
# 35                                                 NA
# 36  [Verse 1]\nI'm so tired of playing\nPlaying wi...
# 46  [Verse 1]\nThis ain't a song for the broken-he...
# 57  [Verse 1]\nPlease come now I think I'm falling...
# 64                                                 NA
# 70  Shatter my bones\nTear out my tongue\nForcing ...
# 71                       This song is an instrumental
# 73                                                 NA
# 74                                                 NA
# 75  She says I smell like safety and home\nI named...
# 76                                                 NA
# 77  [Verse 1]\nHow would you know?\nWhen everythin...
# 83  [Verse 1]\nIf I ever leave this world alive\nI...
# 87  [Instrumental]\n\nShe said 'I'm leaving\nAnd t...
# 89                                                 NA

# %%
df.to_csv('playlist_info.csv',index = False)

# %% [markdown]
# # NEO4J DB

# %%
print(comments_info[:200])
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [('DeeCee', 1403638235, [{'tag': 'p', 'children': ['We should embrace the contractions here! The “It is"s don’t fit with how the song is actually sung; Jacoby is clearly using "it’s”. And to me it sounds like he’s singing “I got” and “I’ve gotta” rather than “I have got” and “I have got to.”']}, '', {'tag': 'p', 'children': ['Arguably nitpicky, yep. :)']}], 'Papa-Roach-To-Be-Loved-lyrics'), ('CySorcerorD', 1494570401, [{'tag': 'p', 'children': ['replace the A with an I to correct the “A love deprevation” to “I love deprevation”']}], 'Papa-Roach-To-Be-Loved-lyrics'), ('guesg', 1620154841, [{'tag': 'p', 'children': ['I love that this song was the theme song for WWE raw from 2006- 2009.']}], 'Papa-Roach-To-Be-Loved-lyrics'), ('SpaceGhostBenoit', 1626561019, [{'tag': 'p', 'children': ['stayed up every school night as a kid just to watch cena edge and DX']}], 'Papa-Roach-To-Be-Loved-lyrics')], [], [('Meandmylife', 1408078858, [{'tag': 'p', 'children': ['you should add ‘hold your drinks’ before the chorus after verse 3']}], 'The-Wanted-We-Own-The-Night-lyrics')], [], [], [], [], [], [], [], [], [], [], [('hafidzalhaidar2', 1492384177, [{'tag': 'p', 'children': ['Good one.']}], 'Pearl-Jam-Got-Some-lyrics')], [], [], [], [], [], [('FreetobeMe', 1438750833, [{'tag': 'p', 'children': ['tfios made me cry and so did this song this is one strong song']}], 'Ed-Sheeran-All-Of-The-Stars-lyrics'), ('ForestStalker', 1487165150, [{'tag': 'p', 'children': ['“So I took your hands back through lamp lit streets, I knew” Not lands and streets.']}], 'Ed-Sheeran-All-Of-The-Stars-lyrics'), ('aryasadeqi', 1457704172, [{'tag': 'p', 'children': ['great']}], 'Ed-Sheeran-All-Of-The-Stars-lyrics'), ('JordanAdan', 1483640571, [{'tag': 'p', 'children': ['ed Sheeran, is an amazing singer omg']}], 'Ed-Sheeran-All-Of-The-Stars-lyrics'), ('anjalimate', 1519727368, [{'tag': 'p', 'children': ['I cried like half of the movie… until this song came on……', {'tag': 'br'}, 'And killed me…..']}], 'Ed-Sheeran-All-Of-The-Stars-lyrics')], [('dexdroses', 1509404308, [{'tag': 'p', 'children': ['):']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('lost_in_the_night', 1581852039, [{'tag': 'p', 'children': ['this song always makes me cry so hard. makes me think about everything i’ve gone through these past few years. whether it be my suicide attempts or how my family thinks i’m too young to question my gender identity or how they  refuse to let me see a therapist because they think i’m okay. i need to get out of here for my sake, but i don’t know where i could even go.']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('NylaTheWolf', 1604596136, [{'tag': 'p', 'children': ['Criminally underrated, beautiful song!']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('sofia_andujar', 1598908736, [{'tag': 'p', 'children': ['my favorite ever quote: “A dark world aches for a splash of the sun”']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('elysavittoria', 1614959322, [{'tag': 'p', 'children': ['this song has such amazing imagery and lyricism. i stand by my opinion that 2010 alternative and indie songs are underrated']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('redbulI', 1621702524, [{'tag': 'p', 'children': ['means a lot to me, I hope you guys can get over everything that happened to you. need a friend to talk, find me -cursetrap']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('TheBlueSpirit', 1631013004, [{'tag': 'p', 'children': [':‘(']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('interstellartunes', 1628526426, [{'tag': 'p', 'children': ['the chorus reminds me of Zero by Imagine Dragons']}], 'Young-the-Giant-Cough-Syrup-lyrics'), ('NisanurAvc', 1638790698, [{'tag': 'p', 'children': ['i love this song so much😭😭😭']}], 'Young-the-Giant-Cough-Syrup-lyrics')], [], [], [], [], [('loverthehater', 1526604347, [{'tag': 'p', 'children': ['Don’t have the points to edit the song info, but the song samples “Czech Lady” in The Conet Project (Disc 1, Track 19) on th ...

# %%
comment_list = [x for x in comments_info if x] #remove [] lists

# %%
comments_list_flat = [item for sublist in comment_list for item in sublist] # Transform list of list in a list

# %%
new_comment_list = []

for cm in comments_list_flat:
    #print(cm)
    txt = ''
    for tag in cm[2]:
        if (type(tag) is dict and tag['tag'] == 'p'):
            if ('children' in tag):
                for words in tag['children']:
                    if(type(words) is dict):
                        txt += '\n'
                    else:
                        txt = txt + words + ' '       
    new_comment_list.append((cm[0],cm[1],txt,cm[3]))

# %%
df_comment_info = pd.DataFrame(new_comment_list,columns=['author','date','comment','artist_track'])

# %%
df_comment_info.to_csv('comments_info.csv',index = False)
